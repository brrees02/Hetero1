# %%
pip install fiona geopandas xgboost gensim folium pyLDAvis descartes
# Out:
# Collecting fiona
#   Obtaining dependency information for fiona from https://files.pythonhosted.org/packages/7f/27/b24c1610c7ae5716709321f04d38d7b8b71ed531f80df4f697b9ad99cfc3/fiona-1.9.5-cp311-cp311-win_amd64.whl.metadata
#   Downloading fiona-1.9.5-cp311-cp311-win_amd64.whl.metadata (51 kB)
#      ---------------------------------------- 0.0/51.1 kB ? eta -:--:--
#      ---------------------------------------- 51.1/51.1 kB 1.3 MB/s eta 0:00:00
# Collecting geopandas
#   Obtaining dependency information for geopandas from https://files.pythonhosted.org/packages/3e/cf/ede993ed7070c5487e6db550aad490178c06eaa48ad26ff5e5263f995fba/geopandas-0.14.1-py3-none-any.whl.metadata
#   Downloading geopandas-0.14.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting xgboost
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/bc/43/242432efc3f60052a4a534dc4926b21e236ab4ec8d4920c593da3f65c65d/xgboost-2.0.2-py3-none-win_amd64.whl.metadata
#   Downloading xgboost-2.0.2-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: gensim in c:\users\breez\anaconda3\lib\site-packages (4.3.0)
# Collecting folium
#   Obtaining dependency information for folium from https://files.pythonhosted.org/packages/a2/1a/37c7ee1bc806d6c32621fecc72c19f6a9f9b4369e5e8f406a7c16d49f031/folium-0.15.0-py2.py3-none-any.whl.metadata
#   Downloading folium-0.15.0-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
#      ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#      ------ --------------------------------- 0.5/2.6 MB 9.6 MB/s eta 0:00:01
#      --------------------- ------------------ 1.4/2.6 MB 15.2 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 MB 20.6 MB/s eta 0:00:01
#      ---------------------------------------- 2.6/2.6 MB 16.6 MB/s eta 0:00:00
# Collecting descartes
#   Downloading descartes-1.1.0-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\breez\anaconda3\lib\site-packages (from fiona) (22.1.0)
# Requirement already satisfied: certifi in c:\users\breez\anaconda3\lib\site-packages (from fiona) (2023.7.22)
# Requirement already satisfied: click~=8.0 in c:\users\breez\anaconda3\lib\site-packages (from fiona) (8.0.4)
# Collecting click-plugins>=1.0 (from fiona)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5 (from fiona)
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six in c:\users\breez\anaconda3\lib\site-packages (from fiona) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\breez\anaconda3\lib\site-packages (from fiona) (68.0.0)
# Requirement already satisfied: packaging in c:\users\breez\anaconda3\lib\site-packages (from geopandas) (23.0)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\breez\anaconda3\lib\site-packages (from geopandas) (1.5.3)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Obtaining dependency information for pyproj>=3.3.0 from https://files.pythonhosted.org/packages/79/95/eb68113c5b5737c342bde1bab92705dabe69c16299c5a122616e50f1fbd6/pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=1.8.0 (from geopandas)
#   Obtaining dependency information for shapely>=1.8.0 from https://files.pythonhosted.org/packages/9e/39/029c441d8af32ab423b229c4525ce5ce6707318155b59634811a4c56f5c4/shapely-2.0.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading shapely-2.0.2-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: numpy in c:\users\breez\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\breez\anaconda3\lib\site-packages (from xgboost) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\breez\anaconda3\lib\site-packages (from gensim) (5.2.1)
# Collecting FuzzyTM>=0.4.0 (from gensim)
#   Downloading FuzzyTM-2.0.5-py3-none-any.whl (29 kB)
# Collecting branca>=0.6.0 (from folium)
#   Obtaining dependency information for branca>=0.6.0 from https://files.pythonhosted.org/packages/2f/e7/603b136221de923055716d23e3047da71f92e0d8ba2c4517ce49a54fe768/branca-0.7.0-py3-none-any.whl.metadata
#   Downloading branca-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\breez\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: requests in c:\users\breez\anaconda3\lib\site-packages (from folium) (2.31.0)
# Collecting pandas>=1.4.0 (from geopandas)
#   Obtaining dependency information for pandas>=1.4.0 from https://files.pythonhosted.org/packages/97/d8/dc2f6bff06a799a5603c414afc6de39c6351fe34892d50b6a077df3be6ac/pandas-2.1.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading pandas-2.1.3-cp311-cp311-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\breez\anaconda3\lib\site-packages (from pyLDAvis) (1.2.0)
# Requirement already satisfied: numexpr in c:\users\breez\anaconda3\lib\site-packages (from pyLDAvis) (2.8.4)
# Collecting funcy (from pyLDAvis)
#   Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\breez\anaconda3\lib\site-packages (from pyLDAvis) (1.3.0)
# Requirement already satisfied: matplotlib in c:\users\breez\anaconda3\lib\site-packages (from descartes) (3.7.1)
# Requirement already satisfied: colorama in c:\users\breez\anaconda3\lib\site-packages (from click~=8.0->fiona) (0.4.6)
# Collecting pyfume (from FuzzyTM>=0.4.0->gensim)
#   Downloading pyFUME-0.2.25-py3-none-any.whl (67 kB)
#      ---------------------------------------- 0.0/67.1 kB ? eta -:--:--
#      ---------------------------------------- 67.1/67.1 kB ? eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\breez\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\breez\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\breez\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2022.7)
# Collecting tzdata>=2022.1 (from pandas>=1.4.0->geopandas)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      ------------------------------------- 341.8/341.8 kB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\breez\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->pyLDAvis) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\breez\anaconda3\lib\site-packages (from matplotlib->descartes) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\breez\anaconda3\lib\site-packages (from matplotlib->descartes) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\breez\anaconda3\lib\site-packages (from matplotlib->descartes) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\breez\anaconda3\lib\site-packages (from matplotlib->descartes) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\breez\anaconda3\lib\site-packages (from matplotlib->descartes) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\breez\anaconda3\lib\site-packages (from matplotlib->descartes) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\breez\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\breez\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\breez\anaconda3\lib\site-packages (from requests->folium) (1.26.16)
# Collecting simpful (from pyfume->FuzzyTM>=0.4.0->gensim)
#   Obtaining dependency information for simpful from https://files.pythonhosted.org/packages/8d/93/8448d3f1aa9d2911b8cba2602aaa1af85eb31a26d28b7b737f1fa5b40c02/simpful-2.11.1-py3-none-any.whl.metadata
#   Downloading simpful-2.11.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting fst-pso (from pyfume->FuzzyTM>=0.4.0->gensim)
#   Downloading fst-pso-1.8.1.tar.gz (18 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting miniful (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim)
#   Downloading miniful-0.0.6.tar.gz (2.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Downloading fiona-1.9.5-cp311-cp311-win_amd64.whl (22.9 MB)
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    --- ------------------------------------ 2.0/22.9 MB 65.1 MB/s eta 0:00:01
#    --------- ------------------------------ 5.5/22.9 MB 70.2 MB/s eta 0:00:01
#    --------------- ------------------------ 9.1/22.9 MB 72.5 MB/s eta 0:00:01
#    ------------------- -------------------- 10.9/22.9 MB 59.5 MB/s eta 0:00:01
#    ------------------------ --------------- 14.0/22.9 MB 65.2 MB/s eta 0:00:01
#    ------------------------------- -------- 17.8/22.9 MB 72.6 MB/s eta 0:00:01
#    --------------------------------- ------ 19.3/22.9 MB 54.7 MB/s eta 0:00:01
#    ---------------------------------------  22.9/22.9 MB 59.5 MB/s eta 0:00:01
#    ---------------------------------------  22.9/22.9 MB 59.5 MB/s eta 0:00:01
#    ---------------------------------------  22.9/22.9 MB 59.5 MB/s eta 0:00:01
#    ---------------------------------------  22.9/22.9 MB 59.5 MB/s eta 0:00:01
#    ---------------------------------------- 22.9/22.9 MB 29.7 MB/s eta 0:00:00
# Downloading geopandas-0.14.1-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 34.2 MB/s eta 0:00:00
# Downloading xgboost-2.0.2-py3-none-win_amd64.whl (99.8 MB)
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    - -------------------------------------- 4.4/99.8 MB 92.4 MB/s eta 0:00:02
#    -- ------------------------------------- 6.8/99.8 MB 72.0 MB/s eta 0:00:02
#    --- ------------------------------------ 8.9/99.8 MB 71.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 12.6/99.8 MB 65.6 MB/s eta 0:00:02
#    ------ --------------------------------- 17.4/99.8 MB 72.6 MB/s eta 0:00:02
#    -------- ------------------------------- 20.6/99.8 MB 72.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 25.4/99.8 MB 93.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 29.8/99.8 MB 93.0 MB/s eta 0:00:01
#    ------------ --------------------------- 31.1/99.8 MB 73.1 MB/s eta 0:00:01
#    -------------- ------------------------- 35.2/99.8 MB 73.1 MB/s eta 0:00:01
#    --------------- ------------------------ 38.5/99.8 MB 65.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 41.4/99.8 MB 81.8 MB/s eta 0:00:01
#    ------------------ --------------------- 45.5/99.8 MB 72.6 MB/s eta 0:00:01
#    ------------------- -------------------- 47.9/99.8 MB 65.6 MB/s eta 0:00:01
#    -------------------- ------------------- 51.2/99.8 MB 81.8 MB/s eta 0:00:01
#    --------------------- ------------------ 54.7/99.8 MB 65.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 56.2/99.8 MB 65.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 58.6/99.8 MB 59.5 MB/s eta 0:00:01
#    ------------------------- -------------- 62.7/99.8 MB 65.6 MB/s eta 0:00:01
#    -------------------------- ------------- 65.8/99.8 MB 73.1 MB/s eta 0:00:01
#    --------------------------- ------------ 69.0/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 72.1/99.8 MB 72.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 74.3/99.8 MB 59.5 MB/s eta 0:00:01
#    ------------------------------- -------- 79.2/99.8 MB 72.6 MB/s eta 0:00:01
#    --------------------------------- ------ 84.0/99.8 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 86.9/99.8 MB 81.8 MB/s eta 0:00:01
#    ------------------------------------ --- 90.5/99.8 MB 81.8 MB/s eta 0:00:01
#    ------------------------------------- -- 94.2/99.8 MB 72.6 MB/s eta 0:00:01
#    ---------------------------------------  98.1/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 81.8 MB/s eta 0:00:01
#    ---------------------------------------- 99.8/99.8 MB 6.1 MB/s eta 0:00:00
# Downloading folium-0.15.0-py2.py3-none-any.whl (100 kB)
#    ---------------------------------------- 0.0/100.3 kB ? eta -:--:--
#    ---------------------------------------- 100.3/100.3 kB ? eta 0:00:00
# Downloading branca-0.7.0-py3-none-any.whl (25 kB)
# Downloading pandas-2.1.3-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ------------- -------------------------- 3.6/10.6 MB 116.6 MB/s eta 0:00:01
#    -------------- ------------------------- 3.7/10.6 MB 47.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.9/10.6 MB 62.8 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 65.6 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 34.4 MB/s eta 0:00:00
# Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl (6.1 MB)
#    ---------------------------------------- 0.0/6.1 MB ? eta -:--:--
#    ------------------------ --------------- 3.7/6.1 MB 77.6 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.1 MB 64.6 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.1 MB 64.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.1/6.1 MB 39.0 MB/s eta 0:00:00
# Downloading shapely-2.0.2-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 44.6 MB/s eta 0:00:00
# Downloading simpful-2.11.1-py3-none-any.whl (32 kB)
# Building wheels for collected packages: fst-pso, miniful
#   Building wheel for fst-pso (setup.py): started
#   Building wheel for fst-pso (setup.py): finished with status 'done'
#   Created wheel for fst-pso: filename=fst_pso-1.8.1-py3-none-any.whl size=20448 sha256=e2342a669f5fb8af9ff19218e90bbcefe72dce37ab1f8327d73b5aad102e3f2b
#   Stored in directory: c:\users\breez\appdata\local\pip\cache\wheels\69\f5\e5\18ad53fe1ed6b2af9fad05ec052e4acbac8e92441df44bad2e
#   Building wheel for miniful (setup.py): started
#   Building wheel for miniful (setup.py): finished with status 'done'
#   Created wheel for miniful: filename=miniful-0.0.6-py3-none-any.whl size=3522 sha256=8442320b2efef8496e95d0978130e683aa79df645d473d5021a0919b6ebb8be7
#   Stored in directory: c:\users\breez\appdata\local\pip\cache\wheels\9d\ff\2f\afe4cd56f47de147407705626517d68bea0f3b74eb1fb168e6
# Successfully built fst-pso miniful
# Installing collected packages: funcy, tzdata, shapely, pyproj, xgboost, simpful, pandas, miniful, cligj, click-plugins, branca, fst-pso, folium, fiona, descartes, pyfume, geopandas, FuzzyTM, pyLDAvis
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# Successfully installed FuzzyTM-2.0.5 branca-0.7.0 click-plugins-1.1.1 cligj-0.7.2 descartes-1.1.0 fiona-1.9.5 folium-0.15.0 fst-pso-1.8.1 funcy-2.0 geopandas-0.14.1 miniful-0.0.6 pandas-2.1.3 pyLDAvis-3.4.1 pyfume-0.2.25 pyproj-3.6.1 shapely-2.0.2 simpful-2.11.1 tzdata-2023.3 xgboost-2.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import patsy
from sklearn import linear_model, ensemble, base, neural_network
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn.utils._testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Triyana_2016_price_women_clean.csv')
df.describe()
# Out:
#           rid_panel          prov   Location_ID           dist          wave  \
# count  1.225100e+04  22768.000000  2.277100e+04   22771.000000  22771.000000
# mean   3.406884e+12     42.761156  4.286882e+06  431842.012033      1.847174
# std    1.944106e+12     14.241982  1.423541e+06  143917.353784      0.875323
# min    1.100103e+10     31.000000  3.175010e+06    3524.000000      1.000000
# 25%    1.731008e+12     32.000000  3.210180e+06  323210.000000      1.000000
# 50%    3.491004e+12     35.000000  3.517171e+06  353517.000000      2.000000
# 75%    5.061008e+12     53.000000  5.307020e+06  535307.000000      3.000000
# max    6.681013e+12     75.000000  7.571030e+06  757571.000000      3.000000
#
#                 edu        agecat  log_xp_percap        rhr031        rhr032  \
# count  22771.000000  22771.000000   22771.000000  22771.000000  22771.000000
# mean      52.765799      4.043081      13.420404      0.675157      0.754908
# std       45.833778      1.280589       1.534089      0.468326      0.430151
# min        6.000000      0.000000       7.461401      0.000000      0.000000
# 25%        6.000000      3.000000      11.972721      0.000000      1.000000
# 50%       12.000000      5.000000      12.851639      1.000000      1.000000
# 75%       99.000000      5.000000      15.018967      1.000000      1.000000
# max       99.000000      5.000000      15.018967      1.000000      1.000000
#
#        ...     hh_xp_all            tv      parabola        fridge  \
# count  ...  22771.000000  22771.000000  22771.000000  22771.000000
# mean   ...      3.839181      0.754908      0.482148      0.498661
# std    ...      1.481982      0.430151      0.499692      0.500009
# min    ...      1.000000      0.000000      0.000000      0.000000
# 25%    ...      3.000000      1.000000      0.000000      0.000000
# 50%    ...      5.000000      1.000000      0.000000      0.000000
# 75%    ...      5.000000      1.000000      1.000000      1.000000
# max    ...      5.000000      1.000000      1.000000      1.000000
#
#           motorbike           car           pig         goat           cow  \
# count  22771.000000  22771.000000  22771.000000  22771.00000  22771.000000
# mean       0.594792      0.470511      0.536691      0.53858      0.515041
# std        0.490943      0.499141      0.498663      0.49852      0.499785
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        0.000000      0.000000      0.000000      0.00000      0.000000
# 50%        1.000000      0.000000      1.000000      1.00000      1.000000
# 75%        1.000000      1.000000      1.000000      1.00000      1.000000
# max        1.000000      1.000000      1.000000      1.00000      1.000000
#
#               horse
# count  22771.000000
# mean       0.470247
# std        0.499125
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 121 columns]

# %%
# some data prep for later
formula = """
bw ~ pkh_kec_ever +
  C(edu)*C(agecat) + log_xp_percap + hh_land + hh_home + C(dist) +
  hh_phone + hh_rf_tile + hh_rf_shingle + hh_rf_fiber +
  hh_wall_plaster + hh_wall_brick + hh_wall_wood + hh_wall_fiber +
  hh_fl_tile + hh_fl_plaster + hh_fl_wood + hh_fl_dirt +
  hh_water_pam + hh_water_mechwell + hh_water_well + hh_water_spring + hh_water_river +
  hh_waterhome +
  hh_toilet_own + hh_toilet_pub + hh_toilet_none +
  hh_waste_tank + hh_waste_hole + hh_waste_river + hh_waste_field +
  hh_kitchen +
  hh_cook_wood + hh_cook_kerosene + hh_cook_gas +
  tv + fridge + motorbike + car + goat + cow + horse
"""
bw, X = patsy.dmatrices(formula, df, return_type="dataframe")
# some categories are empty after dropping rows will Null, drop now
X = X.loc[:, X.sum() > 0]
bw = bw.iloc[:, 0]
treatment_variable = "pkh_kec_ever"
treatment = X["pkh_kec_ever"]
Xl = X.drop(["Intercept", "pkh_kec_ever", "C(dist)[T.313175]"], axis=1)
#scale = bw.std()
#center = bw.mean()
loc_id = df.loc[X.index, "Location_ID"].astype("category")

import re
# remove [ ] from names for compatibility with xgboost
Xl = Xl.rename(columns=lambda x: re.sub('\[|\]','_',x))

# %%
# Estimate average treatment effects
from statsmodels.iolib.summary2 import summary_col
tmp = pd.DataFrame(dict(birthweight=bw,treatment=treatment,assisted_delivery=df.loc[X.index, "good_assisted_delivery"]))
usage = smf.ols("assisted_delivery ~ treatment", data=tmp).fit(cov_type="cluster", cov_kwds={'groups':loc_id})
health= smf.ols("bw ~ treatment", data=tmp).fit(cov_type="cluster", cov_kwds={'groups':loc_id})
summary_col([usage, health])
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#
# ==========================================
#                assisted_delivery     bw
# ------------------------------------------
# Intercept      0.7827            3173.4067
#                (0.0124)          (10.2323)
# treatment      0.0235            -14.8992
#                (0.0192)          (24.6304)
# R-squared      0.0004            0.0001
# R-squared Adj. 0.0002            -0.0001
# ==========================================
# Standard errors in parentheses.
# """

# %%
# for clustering standard errors
def get_treatment_se(fit, cluster_id, rows=None):
    if cluster_id is not None:
        if rows is None:
            rows = [True] * len(cluster_id)
        vcov = sm.stats.sandwich_covariance.cov_cluster(fit, cluster_id.loc[rows])
        return np.sqrt(np.diag(vcov))

    return fit.HC0_se

# %%
def generic_ml_model(x, y, treatment, model, n_split=10, n_group=5, cluster_id=None):
    nobs = x.shape[0]

    blp = np.zeros((n_split, 2))
    blp_se = blp.copy()
    gate = np.zeros((n_split, n_group))
    gate_se = gate.copy()

    baseline = np.zeros((nobs, n_split))
    cate = baseline.copy()
    lamb = np.zeros((n_split, 2))

    for i in range(n_split):
        main = np.random.rand(nobs) > 0.5
        rows1 = ~main & (treatment == 1)
        rows0 = ~main & (treatment == 0)

        mod1 = base.clone(model).fit(x.loc[rows1, :], (y.loc[rows1]))
        mod0 = base.clone(model).fit(x.loc[rows0, :], (y.loc[rows0]))

        B = mod0.predict(x)
        S = mod1.predict(x) - B
        baseline[:, i] = B
        cate[:, i] = S
        ES = S.mean()

        ## BLP
        # assume P(treat|x) = P(treat) = mean(treat)
        p = treatment.mean()
        reg_df = pd.DataFrame(dict(
            y=y, B=B, treatment=treatment, S=S, main=main, excess_S=S-ES
        ))
        reg = smf.ols("y ~ B + I(treatment-p) + I((treatment-p)*(S-ES))", data=reg_df.loc[main, :])
        reg_fit = reg.fit()
        blp[i, :] = reg_fit.params.iloc[2:4]
        blp_se[i, :] = get_treatment_se(reg_fit, cluster_id, main)[2:]

        lamb[i, 0] = reg_fit.params.iloc[-1]**2 * S.var()

        ## GATEs
        cutoffs = np.quantile(S, np.linspace(0,1, n_group + 1))
        cutoffs[-1] += 1
        for k in range(n_group):
            reg_df[f"G{k}"] = (cutoffs[k] <= S) & (S < cutoffs[k+1])

        g_form = "y ~ B + " + " + ".join([f"I((treatment-p)*G{k})" for k in range(n_group)])
        g_reg = smf.ols(g_form, data=reg_df.loc[main, :])
        g_fit = g_reg.fit()
        gate[i, :] = g_fit.params.values[2:] #g_fit.params.filter(regex="G").values
        gate_se[i, :] = get_treatment_se(g_fit, cluster_id, main)[2:]

        lamb[i, 1] = (gate[i,:]**2).sum()/n_group

    out = dict(
        gate=gate, gate_se=gate_se,
        blp=blp, blp_se=blp_se,
        Lambda=lamb, baseline=baseline, cate=cate,
        name=type(model).__name__
    )
    return out

def generic_ml_summary(generic_ml_output):
    out = {
        x: np.nanmedian(generic_ml_output[x], axis=0)
        for x in ["blp", "blp_se", "gate", "gate_se", "Lambda"]
    }
    out["name"] = generic_ml_output["name"]
    return out

# %%
kw = dict(x=Xl, treatment=treatment, n_split=11, n_group=5, cluster_id=loc_id)
@ignore_warnings (category=ConvergenceWarning)
def evaluate_models(models, y, **other_kw):
    all_kw = kw.copy()
    all_kw["y"] = y
    all_kw.update(other_kw)
    return list(map(lambda x: generic_ml_model(model=x, **all_kw), models))

# %%
def generate_report(results):
    summaries = list(map(generic_ml_summary, results))
    df_plot = pd.DataFrame({
        mod["name"]: np.median(mod["cate"], axis=1)
        for mod in results
    })

    print("Correlation in median CATE:")
    display(df_plot.corr())
    sns.pairplot(df_plot, diag_kind="kde", kind="reg")

    print("\n\nBest linear projection of CATE")
    df_cate = pd.concat({
        s["name"]: pd.DataFrame(dict(blp=s["blp"], se=s["blp_se"]))
        for s in summaries
    }).T.stack()
    display(df_cate)

    print("\n\nGroup average treatment effects:")
    df_groups = pd.concat({
        s["name"]: pd.DataFrame(dict(gate=s["gate"], se=s["gate_se"]))
        for s in summaries
    }).T.stack()
    display(df_groups)

# %%
import xgboost as xgb
models = [
    linear_model.LassoCV(cv=10, n_alphas=25, max_iter=500, tol=1e-4, n_jobs=1),
    ensemble.RandomForestRegressor(n_estimators=200, min_samples_leaf=20),
    xgb.XGBRegressor(n_estimators=200, max_depth=3, reg_lambda=2.0, reg_alpha=0.0, objective="reg:squarederror"),
    neural_network.MLPRegressor(hidden_layer_sizes=(20, 10), max_iter=500, activation="logistic",
                                solver="adam", tol=1e-3, early_stopping=True, alpha=0.0001)
]
results = evaluate_models(models, y=bw)
generate_report(results)
# Out:
# Correlation in median CATE:
#                         LassoCV  RandomForestRegressor  XGBRegressor  \
# LassoCV                1.000000               0.551879      0.182736
# RandomForestRegressor  0.551879               1.000000      0.521005
# XGBRegressor           0.182736               0.521005      1.000000
# MLPRegressor          -0.102905              -0.119770     -0.080766
#
#                        MLPRegressor
# LassoCV                   -0.102905
# RandomForestRegressor     -0.119770
# XGBRegressor              -0.080766
# MLPRegressor               1.000000
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Best linear projection of CATE
#          LassoCV  RandomForestRegressor  XGBRegressor  MLPRegressor
# blp 0  -6.939915              -1.274102    -11.943794    -23.893769
#     1  -0.243898              -0.032575      0.124880    643.255995
# se  0  33.527575              32.095824     33.560217     32.825170
#     1   0.875278               0.271710      0.080401   3082.567852
# Group average treatment effects:
#           LassoCV  RandomForestRegressor  XGBRegressor  MLPRegressor
# gate 0  -8.037154              -4.571806    -54.104761    -45.107128
#      1  30.264614              21.247052    -26.988116    -10.962609
#      2  -0.076044              14.684183    -56.767314     -4.906748
#      3 -11.314789             -16.381358      3.961816    -14.930636
#      4 -43.646935              -7.566629     60.577205    -26.765628
# se   0  69.135672              70.723095     66.647810     74.368961
#      1  71.068103              68.617219     68.303812     67.901021
#      2  67.795171              69.443061     69.993183     71.485430
#      3  73.006757              65.947953     69.700279     68.683229
#      4  70.682680              74.059805     79.166931     61.593764

# %%
ad = df.loc[X.index, "good_assisted_delivery"]#"midwife_birth"]
results_ad = evaluate_models(models, y=ad)
generate_report(results_ad)
# Out:
# Correlation in median CATE:
#                         LassoCV  RandomForestRegressor  XGBRegressor  \
# LassoCV                1.000000               0.839128      0.547924
# RandomForestRegressor  0.839128               1.000000      0.574527
# XGBRegressor           0.547924               0.574527      1.000000
# MLPRegressor           0.860993               0.722401      0.446866
#
#                        MLPRegressor
# LassoCV                    0.860993
# RandomForestRegressor      0.722401
# XGBRegressor               0.446866
# MLPRegressor               1.000000
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Best linear projection of CATE
#         LassoCV  RandomForestRegressor  XGBRegressor  MLPRegressor
# blp 0  0.038012               0.037586      0.043823      0.033951
#     1  0.491989               0.551440      0.129845      0.426423
# se  0  0.020448               0.021117      0.022087      0.021331
#     1  0.129211               0.147027      0.075416      0.136080
# Group average treatment effects:
#          LassoCV  RandomForestRegressor  XGBRegressor  MLPRegressor
# gate 0 -0.050564              -0.069108     -0.001165     -0.004959
#      1 -0.037011              -0.000027      0.045695     -0.026947
#      2  0.037012              -0.016032      0.029203     -0.037100
#      3  0.081129               0.058735      0.055904      0.047123
#      4  0.174465               0.198303      0.092929      0.180171
# se   0  0.041331               0.049742      0.049487      0.029726
#      1  0.042659               0.047360      0.051400      0.044990
#      2  0.045607               0.045171      0.040333      0.046996
#      3  0.045216               0.044210      0.044269      0.051001
#      4  0.050526               0.052203      0.048707      0.056704

# %%
df2 = df.loc[X.index, :]
df2["edu99"] = df2.edu == 99
df2["educ"] = df2["edu"]
df2.loc[df2["edu99"], "educ"] = np.nan

variables = [
"log_xp_percap","agecat","educ","tv","goat",
"cow","motorbike","hh_cook_wood","pkh_ever"
]

# %%
def cov_mean_by_group(y, res, cluster_id):
    n_group = res["gate"].shape[1]
    gate = res["gate"].copy()
    gate_se = gate.copy()
    dat = y.to_frame()

    for i in range(res["cate"].shape[1]):
        S = res["cate"][:, i]
        cutoffs = np.quantile(S, np.linspace(0, 1, n_group+1))
        cutoffs[-1] += 1
        for k in range(n_group):
            dat[f"G{k}"] = ((cutoffs[k] <= S) & (S < cutoffs[k+1])) * 1.0

        g_form = "y ~ -1 + " + " + ".join([f"G{k}" for k in range(n_group)])
        g_reg = smf.ols(g_form, data=dat.astype(float))
        g_fit = g_reg.fit()
        gate[i, :] = g_fit.params.filter(regex="G").values
        rows = ~y.isna()
        gate_se[i, :] = get_treatment_se(g_fit, cluster_id, rows)

    out = pd.DataFrame(dict(
        mean=np.nanmedian(gate, axis=0),
        se=np.nanmedian(gate_se, axis=0),
        group=list(range(n_group))
    ))

    return out

# %%
def compute_group_means_for_results(results):
    to_cat = []
    for res in results:
        for v in variables:
            to_cat.append(
                cov_mean_by_group(df2[v], res, loc_id)
                .assign(method=res["name"], variable=v)
            )

    group_means = pd.concat(to_cat, ignore_index=True)
    group_means["plus2sd"] = group_means.eval("mean + 1.96*se")
    group_means["minus2sd"] = group_means.eval("mean - 1.96*se")
    return group_means

# %%
group_means_ad = compute_group_means_for_results(results_ad)

# %%
g = sns.FacetGrid(group_means_ad, col="variable", col_wrap=3, hue="method", sharey=False)
g.map(plt.plot, "group", "mean")
g.map(plt.plot, "group", "plus2sd", ls="--")
g.map(plt.plot, "group", "minus2sd", ls="--")
g.add_legend();
# Out:
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\breez\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
